# %% [markdown]
# <a href="https://colab.research.google.com/github/nidhisharma57350/Machine-Learning/blob/main/House_Price_Prediction_Using_Multiple_Algorithms.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # HOUSE PRICE PREDICTION PROJECT USING MULTIPLE MACHINE LEARNING ALGORITHMS

# %%
import pandas as pd

# %%
import numpy as np

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("House_Data.csv")

# %%
print(df.head()) # It shows by default first 5 rows.
# Out:
#    Sqft  Bedrooms  Bathrooms  YearBuilt  LocationCode       Price
# 0  3774         2          4       2006             1  1279483.77
# 1  1460         4          4       1981             3   748298.12
# 2  1894         2          3       2020             1   768986.29
# 3  1730         5          4       1992             4   871720.14
# 4  1695         5          1       1988             5   834730.66

# %%
print(df.head(10)) # It shows first 10 rows(we can set number of rows according to our requirment.)
# Out:
#    Sqft  Bedrooms  Bathrooms  YearBuilt  LocationCode       Price
# 0  3774         2          4       2006             1  1279483.77
# 1  1460         4          4       1981             3   748298.12
# 2  1894         2          3       2020             1   768986.29
# 3  1730         5          4       1992             4   871720.14
# 4  1695         5          1       1988             5   834730.66
# 5  3692         1          1       2015             5  1420068.59
# 6  2238         5          4       2001             5  1140324.45
# 7  2769         1          2       2021             2   979032.52
# 8  1066         4          4       2005             1   556769.61
# 9  1838         2          4       1991             4   900678.83

# %%
print(df.tail()) # It shows by default bottom 5 rows.
# Out:
#      Sqft  Bedrooms  Bathrooms  YearBuilt  LocationCode       Price
# 995  2569         2          1       2015             2   857928.50
# 996   660         4          4       2010             4   570720.48
# 997  3281         1          2       1981             5  1279230.12
# 998  3722         1          3       1995             3  1435726.90
# 999  1628         5          3       1988             5   953762.59

# %%
print(df.tail(10)) # It shows bottom 10 rows(we can set number of rows according to our requirment.)
# Out:
#      Sqft  Bedrooms  Bathrooms  YearBuilt  LocationCode       Price
# 990  2487         3          2       2020             3   992780.09
# 991  3866         2          2       1992             1  1292977.53
# 992  1266         3          3       1997             4   644628.69
# 993   692         2          1       2016             3   365953.88
# 994  1271         5          2       1992             3   674085.30
# 995  2569         2          1       2015             2   857928.50
# 996   660         4          4       2010             4   570720.48
# 997  3281         1          2       1981             5  1279230.12
# 998  3722         1          3       1995             3  1435726.90
# 999  1628         5          3       1988             5   953762.59

# %%
print(df.info()) # It gives all the information about the dataset.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Sqft          1000 non-null   int64
#  1   Bedrooms      1000 non-null   int64
#  2   Bathrooms     1000 non-null   int64
#  3   YearBuilt     1000 non-null   int64
#  4   LocationCode  1000 non-null   int64
#  5   Price         1000 non-null   float64
# dtypes: float64(1), int64(5)
# memory usage: 47.0 KB
# None

# %%
print(df.isnull()) # It shows there are null values in the dataset or not.(if yes then it return True else False)
# Out:
#       Sqft  Bedrooms  Bathrooms  YearBuilt  LocationCode  Price
# 0    False     False      False      False         False  False
# 1    False     False      False      False         False  False
# 2    False     False      False      False         False  False
# 3    False     False      False      False         False  False
# 4    False     False      False      False         False  False
# ..     ...       ...        ...        ...           ...    ...
# 995  False     False      False      False         False  False
# 996  False     False      False      False         False  False
# 997  False     False      False      False         False  False
# 998  False     False      False      False         False  False
# 999  False     False      False      False         False  False
#
# [1000 rows x 6 columns]

# %%
print(df.isnull().sum()) # It returns the total number of null values in each column.
# Out:
# Sqft            0
# Bedrooms        0
# Bathrooms       0
# YearBuilt       0
# LocationCode    0
# Price           0
# dtype: int64

# %%
print(df.describe()) # It returns the statistics of the dataset.
# Out:
#               Sqft     Bedrooms    Bathrooms    YearBuilt  LocationCode  \
# count  1000.000000  1000.000000  1000.000000  1000.000000   1000.000000
# mean   2338.002000     2.976000     2.483000  2001.104000      3.001000
# std     989.801851     1.421775     1.135341    12.175032      1.421626
# min     601.000000     1.000000     1.000000  1980.000000      1.000000
# 25%    1476.750000     2.000000     1.000000  1991.000000      2.000000
# 50%    2294.000000     3.000000     2.000000  2001.000000      3.000000
# 75%    3276.250000     4.000000     4.000000  2012.000000      4.000000
# max    3998.000000     5.000000     4.000000  2022.000000      5.000000
#
#               Price
# count  1.000000e+03
# mean   9.514299e+05
# std    3.071842e+05
# min    2.548069e+05
# 25%    6.846308e+05
# 50%    9.372101e+05
# 75%    1.208772e+06
# max    1.614792e+06

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
plt.figure(figsize = (8,6))
sns.heatmap(df.corr(numeric_only = True),annot = True,cmap = "coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.scatter(df["Sqft"],df["Price"],marker = "*",color = "red",label = "Sqft vs Price")
plt.xlabel("Sqft")
plt.ylabel("Price")
plt.title("Sqft vs Price")
plt.legend(loc= "upper left")
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.scatter(df["Bedrooms"],df["Price"],marker = "*",color = "purple",label = "Bedrooms vs Price")
plt.xlabel("Bedrooms")
plt.ylabel("Price")
plt.title("Bedrooms vs Price")
plt.legend(loc= "upper left")
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.scatter(df["Bathrooms"],df["Price"],marker = "*",color = "green",label = "Bathrooms vs Price")
plt.xlabel("Bathrooms")
plt.ylabel("Price")
plt.title("Bathrooms vs Price")
plt.legend(loc= "upper right")
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.scatter(df["YearBuilt"],df["Price"],marker = "*",color = "grey",label = "YearBuilt vs Price")
plt.xlabel("YearBuilt")
plt.ylabel("Price")
plt.title("YearBuilt vs Price")
plt.legend(loc= "upper right")
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.scatter(df["Bathrooms"],df["Price"],marker = "*",color = "orange",label = "LocationCode vs Price")
plt.xlabel("LocationCode")
plt.ylabel("Price")
plt.title("LocationCode vs Price")
plt.legend(loc= "upper right")
plt.show()

# %%
x = df[["Sqft","Bedrooms","Bathrooms","YearBuilt","LocationCode"]] # Input Variables

# %%
y = df["Price"] # Output Variable

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.preprocessing import StandardScaler

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state = 42) # 80% data splits in training and 20% in testing.

# %%
scaler = StandardScaler()

# %%
x_train = scaler.fit_transform(x_train)

# %%
x_test = scaler.transform(x_test)

# %%
print(x_train.shape)
# Out:
# (800, 5)

# %%
print(len(x_train))
# Out:
# 800

# %%
print(x_test.shape)
# Out:
# (200, 5)

# %%
print(len(x_test))
# Out:
# 200

# %%
print(y_train.shape)
# Out:
# (800,)

# %%
print(len(y_train))
# Out:
# 800

# %%
print(y_test.shape)
# Out:
# (200,)

# %%
print(len(y_test))
# Out:
# 200

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.metrics import mean_absolute_error, mean_squared_error, root_mean_squared_error, r2_score

# %%
models={
        "Linear regression":LinearRegression(),
        "Decision tree Regression":DecisionTreeRegressor(),
        "Random Forest regression":RandomForestRegressor(),
        "Gradient boosting regression":GradientBoostingRegressor(),
        "KNeighbors regression":KNeighborsRegressor(),
        "Support Vector Regression":SVR()
}

# %%
Sqft = int(input("Enter the value of Sqft:"))
Bedrooms = int(input("Enter No. of bedrooms:"))
Bathrooms = int(input("Enter No. of bathrooms:"))
YearBuilt = int(input("Enter year built:"))
LocationCode = int(input("Enter Location Code:"))
user_input=np.array([[Sqft,Bedrooms,Bathrooms,YearBuilt,LocationCode]])
# Out:
# Enter the value of Sqft:3000
# Enter No. of bedrooms:4
# Enter No. of bathrooms:3
# Enter year built:2018
# Enter Location Code:3

# %%
best_model = None
best_r2 = -1
for model_name,model in models.items():
    model.fit(x_train,y_train)
    y_pred=model.predict(x_test)
    user_pred=model.predict(user_input)
    print(f"Model Name is {model_name}")
    print("pred_price",user_pred)
    print("mae:",mean_absolute_error(y_test,y_pred))
    print("mse:",mean_squared_error(y_test,y_pred))
    print("rmse:",root_mean_squared_error(y_test,y_pred))
    R2_score = r2_score(y_test,y_pred)
    print("r2 score:",R2_score)
    plt.figure(figsize=(6,6))
    plt.scatter(y_test,y_test,marker = "*",color = "red",label = "Actual Value")
    plt.scatter(y_test,y_pred,marker = "+",color = "green",label = "Predicted Value")
    plt.xlabel("Actual House Price")
    plt.ylabel("Predicted House Price")
    plt.title(f"Actual vs Predicted House Prices according to {model_name}")
    plt.legend(loc = "upper left")
    plt.show()
    if R2_score > best_r2:
       best_r2 = R2_score
       best_model = model
    print("*************************************")
    print("*************************************")
    print("*************************************")
print("Best Model:",best_model)
print("Best R2 score:",best_r2)
# Out:
# Model Name is Linear regression
# pred_price [8.81177221e+08]
# mae: 25992.829544607328
# mse: 1077619396.5800626
# rmse: 32827.11374123626
# r2 score: 0.9888245851717382
# *************************************
# *************************************
# *************************************
# Model Name is Decision tree Regression
# pred_price [1579931.9]
# mae: 45970.5959
# mse: 3337583272.3150244
# rmse: 57771.820746061174
# r2 score: 0.9653877076541498
# *************************************
# *************************************
# *************************************
# Model Name is Random Forest regression
# pred_price [1547996.6302]
# mae: 32227.997963499976
# mse: 1622367484.2866285
# rmse: 40278.62316771303
# r2 score: 0.9831752938947406
# *************************************
# *************************************
# *************************************
# Model Name is Gradient boosting regression
# pred_price [1562405.6540058]
# mae: 28358.595064292083
# ...
